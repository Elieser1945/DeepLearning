# %% [markdown]
# # **📌 Bidirectional RNN - Deteksi Sarkasme**

# %% [markdown]
# # Install Library

# %%
# !pip install numpy matplotlib scikit-learn torch tensorflow
# %pip install numpy matplotlib scikit-learn torch tensorflow[and-cuda] keras-tuner nltk

# %% [markdown]
# # Import Library

# %%
import json
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, roc_curve
import matplotlib.pyplot as plt
import keras_tuner as kt
import requests

# %% [markdown]
# # Data Preparation

# %%
# Ambil data mentah
url = 'https://raw.githubusercontent.com/farrelrassya/teachingMLDL/refs/heads/main/02.%20Deep%20Learning/06.%20Week%206/Datasets/DeteksiSarkasme.json'
response = requests.get(url)

# Pisahkan setiap baris, lalu decode masing-masing JSON
data = [json.loads(line) for line in response.text.split('\n') if line.strip()]

# Cek sampel
print("Jumlah data:", len(data))
print("Contoh data:", data[0])
# Out:
# Jumlah data: 26709
# Contoh data: {'article_link': 'https://www.huffingtonpost.com/entry/versace-black-code_us_5861fbefe4b0de3a08f600d5', 'headline': "former versace store clerk sues over secret 'black code' for minority shoppers", 'is_sarcastic': 0}

# %%
sentences = [item['headline'] for item in data]
labels = [item['is_sarcastic'] for item in data]

# %%
# Tokenisasi
vocab_size = 10000
oov_tok = ""
tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(sentences)
sequences = tokenizer.texts_to_sequences(sentences)
padded = pad_sequences(sequences, padding='post', maxlen=100)

# Split data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(padded, labels, test_size=0.2, random_state=42)

# %% [markdown]
# # Hyperparameter Tuning Bidirectional RNN

# %%
def build_model(hp):
    model = tf.keras.Sequential()

    # Embedding layer dengan tuning dimension
    model.add(tf.keras.layers.Embedding(
        input_dim=vocab_size,
        output_dim=hp.Int('embed_dim', 32, 128, step=32)
    ))

    # Bidirectional RNN dengan dropout
    model.add(tf.keras.layers.Bidirectional(
        tf.keras.layers.SimpleRNN(
            units=hp.Int('rnn_units', 32, 128, step=32),
            dropout=hp.Choice('dropout_rate', [0.2, 0.3, 0.5]),
            return_sequences=False
        )
    ))

    # Output layer
    model.add(tf.keras.layers.Dense(1, activation='sigmoid'))

    # Compile model
    model.compile(
        loss='binary_crossentropy',
        optimizer=tf.keras.optimizers.Adam(hp.Choice('lr', [1e-3, 1e-4])),
        metrics=['accuracy']
    )

    return model


# Tuning
tuner = kt.RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=5,
    executions_per_trial=1,
    directory='sarcasm_rnn_tuner',
    project_name='simple_rnn_tuning'
)

tuner.search(X_train, np.array(y_train), epochs=5, validation_split=0.2)
best_model = tuner.get_best_models(num_models=1)[0]
# Out:
# Trial 5 Complete [00h 02m 25s]
# val_accuracy: 0.8656995892524719
#
# Best val_accuracy So Far: 0.8656995892524719
# Total elapsed time: 00h 16m 03s

# %% [markdown]
# # Latih Model

# %%
history = best_model.fit(X_train, np.array(y_train), epochs=25, validation_data=(X_test, np.array(y_test)))
# Out:
# Epoch 1/25
# 668/668 [==============================] - 28s 42ms/step - loss: 0.0180 - accuracy: 0.9943 - val_loss: 0.6513 - val_accuracy: 0.8428
# Epoch 2/25
# 668/668 [==============================] - 30s 44ms/step - loss: 0.0279 - accuracy: 0.9901 - val_loss: 0.6454 - val_accuracy: 0.8426
# Epoch 3/25
# 668/668 [==============================] - 32s 48ms/step - loss: 0.0222 - accuracy: 0.9925 - val_loss: 0.7221 - val_accuracy: 0.8364
# Epoch 4/25
# 668/668 [==============================] - 34s 51ms/step - loss: 0.0085 - accuracy: 0.9973 - val_loss: 0.7287 - val_accuracy: 0.8435
# Epoch 5/25
# 668/668 [==============================] - 48s 71ms/step - loss: 0.0056 - accuracy: 0.9984 - val_loss: 0.8117 - val_accuracy: 0.8405
# Epoch 6/25
# 668/668 [==============================] - 35s 53ms/step - loss: 0.0063 - accuracy: 0.9979 - val_loss: 0.8075 - val_accuracy: 0.8360
# Epoch 7/25
# 668/668 [==============================] - 30s 44ms/step - loss: 0.0103 - accuracy: 0.9966 - val_loss: 0.8296 - val_accuracy: 0.8396
# Epoch 8/25
# 668/668 [==============================] - 29s 44ms/step - loss: 0.0060 - accuracy: 0.9980 - val_loss: 0.8938 - val_accuracy: 0.8341
# Epoch 9/25
# 668/668 [==============================] - 29s 43ms/step - loss: 0.0659 - accuracy: 0.9776 - val_loss: 0.7747 - val_accuracy: 0.8300
# Epoch 10/25
# 668/668 [==============================] - 28s 41ms/step - loss: 0.0108 - accuracy: 0.9962 - val_loss: 0.8079 - val_accuracy: 0.8356
# Epoch 11/25
# 668/668 [==============================] - 28s 42ms/step - loss: 0.0044 - accuracy: 0.9991 - val_loss: 0.8565 - val_accuracy: 0.8349
# Epoch 12/25
# 668/668 [==============================] - 29s 43ms/step - loss: 0.0028 - accuracy: 0.9992 - val_loss: 0.8951 - val_accuracy: 0.8353
# Epoch 13/25
# 668/668 [==============================] - 27s 41ms/step - loss: 0.0027 - accuracy: 0.9993 - val_loss: 0.9041 - val_accuracy: 0.8328
# Epoch 14/25
# 668/668 [==============================] - 27s 41ms/step - loss: 0.0032 - accuracy: 0.9990 - val_loss: 0.9673 - val_accuracy: 0.8362
# Epoch 15/25
# 668/668 [==============================] - 28s 42ms/step - loss: 0.0044 - accuracy: 0.9984 - val_loss: 1.0377 - val_accuracy: 0.8358
# Epoch 16/25
# 668/668 [==============================] - 28s 43ms/step - loss: 0.0053 - accuracy: 0.9981 - val_loss: 0.9759 - val_accuracy: 0.8272
# Epoch 17/25
# 668/668 [==============================] - 27s 41ms/step - loss: 0.0050 - accuracy: 0.9979 - val_loss: 1.0484 - val_accuracy: 0.8345
# Epoch 18/25
# 668/668 [==============================] - 27s 41ms/step - loss: 0.0034 - accuracy: 0.9989 - val_loss: 1.0518 - val_accuracy: 0.8341
# Epoch 19/25
# 668/668 [==============================] - 27s 41ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 1.1116 - val_accuracy: 0.8261
# Epoch 20/25
# 668/668 [==============================] - 29s 43ms/step - loss: 0.0036 - accuracy: 0.9988 - val_loss: 1.1140 - val_accuracy: 0.8246
# Epoch 21/25
# 668/668 [==============================] - 27s 41ms/step - loss: 0.0044 - accuracy: 0.9985 - val_loss: 1.0629 - val_accuracy: 0.8336
# Epoch 22/25
# 668/668 [==============================] - 28s 42ms/step - loss: 0.0038 - accuracy: 0.9985 - val_loss: 1.1393 - val_accuracy: 0.8282
# Epoch 23/25
# 668/668 [==============================] - 28s 42ms/step - loss: 0.0046 - accuracy: 0.9984 - val_loss: 1.1830 - val_accuracy: 0.8280
# Epoch 24/25
# 668/668 [==============================] - 29s 43ms/step - loss: 0.0048 - accuracy: 0.9983 - val_loss: 1.1591 - val_accuracy: 0.8298
# Epoch 25/25
# 668/668 [==============================] - 28s 42ms/step - loss: 0.0021 - accuracy: 0.9992 - val_loss: 1.1582 - val_accuracy: 0.8310

# %% [markdown]
# # Visualisasi

# %%
# Visualisasi Akurasi dan Loss
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title("Accuracy")
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title("Loss")
plt.legend()
plt.show()

# %% [markdown]
# # Evaluasi Model

# %%
y_pred_prob = best_model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype("int32")

acc = accuracy_score(y_test, y_pred)
prec = precision_score(y_test, y_pred)
rec = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
auc = roc_auc_score(y_test, y_pred_prob)

print("=====Evaluasi Model=====")
print(f"Akurasi  : {acc:.4f}")
print(f"Presisi  : {prec:.4f}")
print(f"Recall   : {rec:.4f}")
print(f"F1-Score : {f1:.4f}")
print(f"AUC      : {auc:.4f}")

# ROC Curve
fpr, tpr, _ = roc_curve(y_test, y_pred_prob)
plt.plot(fpr, tpr, label=f'AUC = {auc:.2f}')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()
# Out:
# 167/167 [==============================] - 1s 7ms/step
# =====Evaluasi Model=====
# Akurasi  : 0.8310
# Presisi  : 0.8484
# Recall   : 0.7489
# F1-Score : 0.7956
# AUC      : 0.9027
